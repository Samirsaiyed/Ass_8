# %% [markdown]
# 1.Is the Python Standard Library included with PyInputPlus?

# %% [markdown]
# Ans : No, PyInputPlus is not a part of Python standard library , it needs to be installed explicitly using the command
# !pip install PyInputPlus

# %% [markdown]
# 2.Why is PyInputPlus commonly imported with import pyinputplus as pypi?

# %% [markdown]
# Ans : you can import the module with import pyinputplus as pyip so that you can enter a shorter name when calling the modules functiona.

# %% [markdown]
# 3.How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# Ans : inputInt() function accepts an interger value. this also takes additional parameters min, max, greterThan and lessThan for bounds. And it always returns an int.

# %% [markdown]
# whereas inputFloat() function accepts a floting-point numeric value. this also takes additional min , max, graterThan and lessThan parameters. and always return a float.

# %% [markdown]
# 4.Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %% [markdown]
# Ans : PyInputPlus module provides a function called as inputInt() which only returns only integer values. inorder to restrict the input between the defined range only.

# %% [markdown]
# import pyinputplus as pyip
# wholenumber = pyip.inputInt(prompt = 'Enter the number: ',min=0, max =100)
# print(wholenumber)

# %% [markdown]
# 5.What is transferred to the keyword arguments allowRegexes and blockRegexes?

# %% [markdown]
# Ans : we can use allowRegexes and blockRegexes keyword arguments to take list of regular expression string to determine what the pyinputplus function will reject or accept valid input.

# %%
6.If a blank input is entered three times, what does inputStr(limit=3) do?
# Out:
# Object `do` not found.

# %% [markdown]
# 6.If a blank input is entered three times, what does inputStr(limit=3) do

# %% [markdown]
# Ans : the statement inputStr(limit=3) will thow two exception ValidationException and RetryLimitException. thr first exception is thorwn because blank values are not allowed by inputStr() function by default. it we want to consider blank values as valid input, we have to set blank=True.

# %% [markdown]
# the second exception is occured because we have reached the max limit we have specified by using limit parameter. inorder to avoid this exception we can use default parameter to return a defualt value when max limit is reached.

# %% [markdown]
# 7.If blank input is entered three times, what does inputStr(limit=3, default=&#39;hello&#39;) do?

# %% [markdown]
# Ans : Since the default parameter is set to hello . after blank input is entered three times instead of raising RetryLimitException exception. the function will reutrn hello as reponse to the calling function.
